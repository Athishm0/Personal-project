# %%
#nodes=["AAC","ACT", "AGC", "ATC", "CAA", "CAG", "CCA", "CGT", "CTG", "GCA", "GCG", "GGT" ,"GTA", "GTT", "TAT", "TCC", "TGC", "TTA"]
#nodes=["AGCG","ATCT","ATGA","ATGG","ATTC","CCCT","CCTG","CTCT","CTGA","CTGC","CTTT","GAAG","GATT","GCGT","GCTC","GTTC","TATG","TCAT","TCTA","TCTT","TGAA","TGAT","TGGA",	"TGTT", "TTCA",	"TTCC","TTTC"]
#nodes="AAC ACT AGC ATC CAA CAG CCA CGT CTG GCA GCG GGT GTA GTT TAT TCC TGC TTA"
nodes="... ... ... ... ..."
nodes= nodes.replace(" ",",")
nodes= nodes.split(" ")
print(nodes)

#I="GACGTGTAGTAGTACGTAGTGCATAGCAT"
#I="CCCTGATTCAT"
#I="..."
#nodes=[]
#for i in range(len(I)-19):
  #nodes.append(I[i:i+20])

nodes.sort()
print(nodes)
c=len(nodes)
print(c)
#c=10



def G(s,v,n,count=c):

  v+=1
  n+=1

  x={}
  #z=[]
  I=[i for i in s ]
  for i in I:
  #print(i[0:2])
   for j in s:
    #print(j[1:3])
    if  i[0:v]==j[1:n]:

      x[j+i[v:n]]=0

  count-=1
  if count!=1:
    z=[]
    for keys in x.keys():
     z.append(keys)
    G(z,v,n,count)

  else:
    print(x)
    #print(x)
    return x


G(nodes,len(nodes[0])-2,len(nodes[0])-1)
# Out:
# ['...,...,...,...,...']
# ['...,...,...,...,...']
# 1
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-2-edb2dfadfdb3> in <cell line: 53>()
#      51
#      52
# ---> 53 G(nodes,len(nodes[0])-2,len(nodes[0])-1)
#      54
#      55
#
# <ipython-input-2-edb2dfadfdb3> in G(s, v, n, count)
#      43     for keys in x.keys():
#      44      z.append(keys)
# ---> 45     G(z,v,n,count)
#      46
#      47   else:
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-edb2dfadfdb3> in G(s, v, n, count)
#      43     for keys in x.keys():
#      44      z.append(keys)
# ---> 45     G(z,v,n,count)
#      46
#      47   else:
#
# RecursionError: maximum recursion depth exceeded

# %%
import sys
sys.setrecursionlimit(1000)
#nodes=["AAC","ACT", "AGC", "ATC", "CAA", "CAG", "CCA", "CGT", "CTG", "GCA", "GCG", "GGT" ,"GTA", "GTT", "TAT", "TCC", "TGC", "TTA"]
#nodes=["AGCG","ATCT","ATGA","ATGG","ATTC","CCCT","CCTG","CTCT","CTGA","CTGC","CTTT","GAAG","GATT","GCGT","GCTC","GTTC","TATG","TCAT","TCTA","TCTT","TGAA","TGAT","TGGA",	"TGTT", "TTCA",	"TTCC","TTTC"]
#nodes="AAC ACT AGC ATC CAA CAG CCA CGT CTG GCA GCG GGT GTA GTT TAT TCC TGC TTA"
#nodes= nodes.replace(" ",",")
#nodes= nodes.split(" ")
#print(nodes)

nodes="... ... ... ... ..."
nodes=nodes.upper()
nodes=nodes.split(" ")

print(nodes)
#I="GACGTGTAGTAGTACGTAGTGCATAGCAT"
#I="CCCTGATTCAT"
#I="..."
node=[]
for x in nodes:
 for i in range(len(x)-599):
  node.append(x[i:i+600])

#node.sort()
print(node)
c=len(node)
print(c)
#c=10



def G(s,v,n):

  v+=1
  n+=1

  x=[]
  #z=[]
  I=[i for i in s ]
  for i in I:
  #print(i[0:2])
   for j in s:
    #print(j[1:3])
    if  i[0:v]==j[1:n]:

      x.append(j+i[v:n])



  if len(x)!=1:



    G(x,v,n)




  else:
    print(x)


G(node,len(node[0])-2,len(node[0])-1)
# Out:
# ['...', '...', '...', '...', '...']
# ...

# %%
x
# Out:
# 't'
