# %%
# !pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 850.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

from chembl_webresource_client.new_client import new_client

# %%
target=new_client.target
target_q=target.search()
targets=pd.DataFrame.from_dict(target_q)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'Huntingtin', 'xref_name': None, ...       Homo sapiens
# 1                                                 []       Homo sapiens
# 2                                                 []       Mus musculus
# 3                                                 []  Rattus norvegicus
# 4                                                 []       Homo sapiens
# 5                                                 []       Homo sapiens
# 6                                                 []  Rattus norvegicus
# 7                                                 []       Homo sapiens
#
#                                            pref_name  score  \
# 0                                         Huntingtin   26.0
# 1  Baculoviral IAP repeat-containing protein 3/Hu...   26.0
# 2                                         Huntingtin   18.0
# 3                                         Huntingtin   18.0
# ...

# %%
selected_tar=targets.target_chembl_id[0]
selected_tar
# Out:
# 'CHEMBL5514'

# %%
act=new_client.activity
res=act.filter(target_chembl_id=selected_tar).filter(standard_type='IC50')

# %%
df=pd.DataFrame.from_dict(res)
df
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 69  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 70  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 71  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 72  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 73  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id activity_properties assay_chembl_id  \
# 0       2274865                  []   CHEMBL1029934
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv',index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
from os import mkdir
mkdir ("/content/gdrive/My Drive/Colab Notebooks/data")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-10-bc03c202faf3> in <cell line: 2>()
#       1 from os import mkdir
# ----> 2 mkdir ("/content/gdrive/My Drive/Colab Notebooks/data")
#
# FileExistsError: [Errno 17] File exists: '/content/gdrive/My Drive/Colab Notebooks/data'

# %%
cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
ls
# Out:
# bioactivity_data.csv  gdrive/  sample_data/

# %%
with open("/content/bioactivity_data.csv") as Data:
  print(Data.read())
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2=df[df.standard_value.notna()]
df2
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 69  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 70  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 71  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 72  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 73  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id activity_properties assay_chembl_id  \
# 0       2274865                  []   CHEMBL1029934
# ...

# %%
bioactivity_class=[]
#x=0
#for e in df2.standard_value:
#  x+=float(e)
#a=x/len(df2.standard_value)
a=1000#nM
#if df2.units[0]=="uM":
#  a/=1000


#print(len(df2.standard_value))

for i in df2.standard_value:
  if float(i)>=(a*10):
    bioactivity_class.append("inactive")
  elif float(i)<=a:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")



df2['0']=bioactivity_class

print(bioactivity_class)
# Out:
# ['active', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'intermediate', 'inactive', 'inactive', 'inactive', 'inactive', 'inactive', 'inactive', 'inactive', 'inactive', 'intermediate', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'active', 'inactive', 'inactive', 'intermediate', 'intermediate', 'intermediate', 'inactive', 'intermediate', 'inactive']
# <ipython-input-42-9b2cfdcefad5>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2.molecule_chembl_id
# Out:
# 0      CHEMBL493153
# 1      CHEMBL493327
# 2      CHEMBL500972
# 3      CHEMBL495005
# 4      CHEMBL494838
#           ...
# 69    CHEMBL5288657
# 70    CHEMBL5289080
# 71    CHEMBL1222380
# 72    CHEMBL5282648
# 73    CHEMBL5282577
# Name: molecule_chembl_id, Length: 67, dtype: object

# %%
mol_cid=[]

for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles=[]
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value=[]
for i in df2.standard_value:
  standard_value.append(i)

# %%
selection=['molecule_chembl_id','canonical_smiles','standard_value','0']

# %%
df2[selection]
# Out:
#    molecule_chembl_id                              canonical_smiles  \
# 0        CHEMBL493153              Oc1ccc(CCNc2ncnc3ccc(Cl)cc23)cc1
# 1        CHEMBL493327  Clc1ccc2ncnc(N3CCN(Cc4ccc5c(c4)OCO5)CC3)c2c1
# 2        CHEMBL500972              Oc1ccc(CCNc2ncnc3ccc(Br)cc23)cc1
# 3        CHEMBL495005                 CN1CCN(c2ncnc3ccc(Br)cc23)CC1
# 4        CHEMBL494838                CCN1CCN(c2ncnc3ccc(Br)cc23)CC1
# ..                ...                                           ...
# 69      CHEMBL5288657        Cc1cccc(OCC(=O)Nc2ccc(Nc3ccccc3)cc2)c1
# 70      CHEMBL5289080          Cc1ccccc1OCC(=O)Nc1ccc(Nc2ccccc2)cc1
# 71      CHEMBL1222380     CCCc1cc(OC(=O)c2ccccc2F)n(-c2cccc(F)c2)n1
# 72      CHEMBL5282648      Nc1nc(C(=O)N2N=C3CCCCC3C2(O)C(F)(F)F)cs1
# 73      CHEMBL5282577                   CCOC(=O)[C@@H](N)CCCNC(=N)N
#
#    standard_value             0
# 0           710.0        active
# 1          1070.0  intermediate
# 2          1110.0  intermediate
# ...

# %%
df2
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 69  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 70  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 71  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 72  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 73  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id activity_properties assay_chembl_id  \
# 0       2274865                  []   CHEMBL1029934
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)],axis=1)
# Out:
#    molecule_chembl_id                              canonical_smiles  \
# 0        CHEMBL493153              Oc1ccc(CCNc2ncnc3ccc(Cl)cc23)cc1
# 1        CHEMBL493327  Clc1ccc2ncnc(N3CCN(Cc4ccc5c(c4)OCO5)CC3)c2c1
# 2        CHEMBL500972              Oc1ccc(CCNc2ncnc3ccc(Br)cc23)cc1
# 3        CHEMBL495005                 CN1CCN(c2ncnc3ccc(Br)cc23)CC1
# 4        CHEMBL494838                CCN1CCN(c2ncnc3ccc(Br)cc23)CC1
# ..                ...                                           ...
# 24                NaN                                           NaN
# 25                NaN                                           NaN
# 26                NaN                                           NaN
# 27                NaN                                           NaN
# 28                NaN                                           NaN
#
#    standard_value             0
# 0           710.0        active
# 1          1070.0  intermediate
# 2          1110.0  intermediate
# ...

# %%
df3
# Out:
#    molecule_chembl_id                              canonical_smiles  \
# 0        CHEMBL493153              Oc1ccc(CCNc2ncnc3ccc(Cl)cc23)cc1
# 1        CHEMBL493327  Clc1ccc2ncnc(N3CCN(Cc4ccc5c(c4)OCO5)CC3)c2c1
# 2        CHEMBL500972              Oc1ccc(CCNc2ncnc3ccc(Br)cc23)cc1
# 3        CHEMBL495005                 CN1CCN(c2ncnc3ccc(Br)cc23)CC1
# 4        CHEMBL494838                CCN1CCN(c2ncnc3ccc(Br)cc23)CC1
# ..                ...                                           ...
# 69      CHEMBL5288657        Cc1cccc(OCC(=O)Nc2ccc(Nc3ccccc3)cc2)c1
# 70      CHEMBL5289080          Cc1ccccc1OCC(=O)Nc1ccc(Nc2ccccc2)cc1
# 71      CHEMBL1222380     CCCc1cc(OC(=O)c2ccccc2F)n(-c2cccc(F)c2)n1
# 72      CHEMBL5282648      Nc1nc(C(=O)N2N=C3CCCCC3C2(O)C(F)(F)F)cs1
# 73      CHEMBL5282577                   CCOC(=O)[C@@H](N)CCCNC(=N)N
#
#    standard_value
# 0           710.0
# 1          1070.0
# 2          1110.0
# 3          1310.0
# 4          2210.0
# ..            ...
# ...

# %%
df2[selection].to_csv('bioactivity_preproccessed_data.csv',index=False)

# %%
ls-1
# Out:
# bioactivity_data.csv
# bioactivity_preproccessed_data.csv
# gdrive/
# sample_data/

# %%
cp bioactivity_preproccessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data      bioactivity_preproccessed_data
# bioactivity_data.csv  bioactivity_preproccessed_data.csv
